# %%
# Set working directory for the notebook
import os, sys
target_dir = "/gsplat/examples"
try:
    os.chdir(target_dir)
    print("Changed working directory to:", os.getcwd())
except Exception as e:
    print("Failed to change directory:", target_dir, "->", e)
# Out:
# Changed working directory to: /gsplat/examples

# %% [markdown]
# Using COLMAP scene data to train a gsplat model

# %%
# Run training from the examples directory (cwd set above)
# !CUDA_VISIBLE_DEVICES=0 python simple_trainer.py default  \
    --data_dir /data/output/hloc/FriedrichsHouse/mvs_workspace --data_factor 1 \
    --save_ply --ply_steps 4000 15000 20000 30000 --ply_format "ply_compressed" \
    --cylinder_center "-3.2130,-9.1810,22.2904" --cylinder_axis "-0.0277,0.7073,0.7064" --cylinder_radius 14.7873 \
    --result_dir /data/output/gspalt/FriedrichsHouse \
    --camera_model pinhole \
    # --with_ut --with_eval3d 
    #--scene_min "-12.5" "-4.0" "-2.0" \
    #--scene_max "15.2" "8.0" "50.0" \
    # --cylinder_center "-1.9435,-10.1475,23.3079" --cylinder_axis "-0.0277,0.7073,0.7064" --cylinder_radius 14.6884 \ old approach
# Out:
# Warning: image_path not found for reconstruction
# [Parser] 75 images, taken by 1 cameras.
# Loading EXIF exposure: 100%|█████████████████| 75/75 [00:00<00:00, 24095.96it/s]
# [Parser] No valid EXIF exposure data found in any image.
# /gsplat/examples/simple_trainer.py:432: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   c_hom = torch.cat([torch.tensor(c_vec), torch.tensor([1.0])])
# /gsplat/examples/simple_trainer.py:438: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   n_vec_trans = rot_mat @ torch.tensor(n_vec)
# [Cyl] World Center: tensor([-3.2130, -9.1810, 22.2904])
# [Cyl] Norm  Center: [-0.71808904 -1.1477468   1.8055665 ]
# [Cyl] Norm  Axis:   [0.01452577 0.02402033 0.03019086]
# Cylinder Pruning Active: r=0.6096
# Scene scale: 1.1075550323840186
# Model initialized. Number of GS: 18294
# ╭────── viser (listening *:7777) ───────╮
# │             ╷                         │
# │   HTTP      │ http://localhost:7777   │
# │   Websocket │ ws://localhost:7777     │
# │             ╵                         │
# ╰───────────────────────────────────────╯
# loss=0.192| sh degree=0| :   2%|▏           | 599/30000 [00:11<08:43, 56.12it/s]Step 600: 2815 GSs duplicated, 5508 GSs split. Now having 26617 GSs.
# Step 600: 338 GSs pruned. Now having 26279 GSs.
# loss=0.163| sh degree=0| :   2%|▎           | 696/30000 [00:12<08:02, 60.69it/s]Step 700: 6899 GSs duplicated, 7420 GSs split. Now having 40598 GSs.
# Step 700: 231 GSs pruned. Now having 40367 GSs.
# loss=0.187| sh degree=0| :   3%|▎           | 800/30000 [00:14<08:56, 54.44it/s]Step 800: 10934 GSs duplicated, 8587 GSs split. Now having 59888 GSs.
# Step 800: 114 GSs pruned. Now having 59774 GSs.
# loss=0.144| sh degree=0| :   3%|▎           | 896/30000 [00:16<08:32, 56.76it/s]Step 900: 14605 GSs duplicated, 9415 GSs split. Now having 83794 GSs.
# Step 900: 127 GSs pruned. Now having 83667 GSs.
# loss=0.189| sh degree=1| :   3%|▍           | 998/30000 [00:18<09:31, 50.79it/s]Step 1000: 18599 GSs duplicated, 9383 GSs split. Now having 111649 GSs.
# Step 1000: 162 GSs pruned. Now having 111487 GSs.
# loss=0.138| sh degree=1| :   4%|▍          | 1096/30000 [00:20<09:45, 49.35it/s]Step 1100: 22993 GSs duplicated, 9298 GSs split. Now having 143778 GSs.
# Step 1100: 174 GSs pruned. Now having 143604 GSs.
# loss=0.182| sh degree=1| :   4%|▍          | 1200/30000 [00:22<10:35, 45.30it/s]Step 1200: 26828 GSs duplicated, 8795 GSs split. Now having 179227 GSs.
# Step 1200: 188 GSs pruned. Now having 179039 GSs.
# loss=0.108| sh degree=1| :   4%|▍          | 1300/30000 [00:25<10:42, 44.64it/s]Step 1300: 29621 GSs duplicated, 8809 GSs split. Now having 217469 GSs.
# Step 1300: 233 GSs pruned. Now having 217236 GSs.
# loss=0.109| sh degree=1| :   5%|▌          | 1400/30000 [00:27<11:24, 41.75it/s]Step 1400: 31733 GSs duplicated, 8259 GSs split. Now having 257228 GSs.
# Step 1400: 272 GSs pruned. Now having 256956 GSs.
# loss=0.103| sh degree=1| :   5%|▌          | 1498/30000 [00:30<13:52, 34.23it/s]Step 1500: 34223 GSs duplicated, 8112 GSs split. Now having 299291 GSs.
# Step 1500: 294 GSs pruned. Now having 298997 GSs.
# loss=0.107| sh degree=1| :   5%|▌          | 1598/30000 [00:33<12:47, 37.01it/s]Step 1600: 34407 GSs duplicated, 7395 GSs split. Now having 340799 GSs.
# Step 1600: 405 GSs pruned. Now having 340394 GSs.
# loss=0.091| sh degree=1| :   6%|▌          | 1698/30000 [00:36<14:51, 31.75it/s]Step 1700: 36155 GSs duplicated, 7302 GSs split. Now having 383851 GSs.
# Step 1700: 326 GSs pruned. Now having 383525 GSs.
# loss=0.101| sh degree=1| :   6%|▋          | 1799/30000 [00:41<28:14, 16.64it/s]Step 1800: 34688 GSs duplicated, 6585 GSs split. Now having 424798 GSs.
# Step 1800: 435 GSs pruned. Now having 424363 GSs.
# loss=0.087| sh degree=1| :   6%|▋          | 1900/30000 [00:46<29:46, 15.73it/s]Step 1900: 34687 GSs duplicated, 6271 GSs split. Now having 465321 GSs.
# Step 1900: 454 GSs pruned. Now having 464867 GSs.
# loss=0.094| sh degree=2| :   7%|▋          | 1998/30000 [00:53<25:57, 17.98it/s]Step 2000: 32779 GSs duplicated, 5992 GSs split. Now having 503638 GSs.
# Step 2000: 480 GSs pruned. Now having 503158 GSs.
# loss=0.076| sh degree=2| :   7%|▊          | 2100/30000 [00:57<17:33, 26.48it/s]Step 2100: 33038 GSs duplicated, 5619 GSs split. Now having 541815 GSs.
# Step 2100: 498 GSs pruned. Now having 541317 GSs.
# loss=0.091| sh degree=2| :   7%|▊          | 2199/30000 [01:01<17:44, 26.12it/s]Step 2200: 30899 GSs duplicated, 5007 GSs split. Now having 577223 GSs.
# Step 2200: 431 GSs pruned. Now having 576792 GSs.
# loss=0.075| sh degree=2| :   8%|▊          | 2273/30000 [01:13<14:54, 30.98it/s]
# Traceback (most recent call last):
#   File "/gsplat/examples/simple_trainer.py", line 1728, in <module>
#     cli(main, cfg, verbose=True)
#   File "/opt/conda/lib/python3.11/site-packages/gsplat/distributed.py", line 360, in cli
#     return _distributed_worker(0, 1, fn=fn, args=args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/gsplat/distributed.py", line 295, in _distributed_worker
#     fn(local_rank, world_rank, world_size, args)
#   File "/gsplat/examples/simple_trainer.py", line 1668, in main
#     runner.train()
#   File "/gsplat/examples/simple_trainer.py", line 1004, in train
#     time.sleep(0.01)
# KeyboardInterrupt
# ^C
# Exception ignored in atexit callback: <bound method WebsockServer.stop of <viser.infra._infra.WebsockServer object at 0x7f133ca99090>>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/viser/infra/_infra.py", line 370, in stop
#     self._server_thread.join(timeout=0.1)
#   File "/opt/conda/lib/python3.11/threading.py", line 1123, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/opt/conda/lib/python3.11/threading.py", line 1139, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:

# %%
# Run training from the examples directory (cwd set above)
# !CUDA_VISIBLE_DEVICES=0 python simple_trainer.py mcmc  \
    --data_dir /data/output/hloc/FriedrichsHouse/mvs_sfm_superpoint_max+lightglue --data_factor 1 \
    --result_dir /data/output/gspalt/FriedrichsHouse \
    --camera_model pinhole \
    --with_ut --with_eval3d
